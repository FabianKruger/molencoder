# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from typing import Dict, Any
import logging
from molencoder.evaluation.statistical_evaluation import repeated_measures_anova, tukey_hsd
from molencoder.utils.experiment_plotting import analyze_and_plot_five_experiments

# %%
csv_paths = [
    "/Users/fabian/Code/smilesencoder/experiments/explicit_vs_not_explicit_hs/adme-fang-hclint-1_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/explicit_vs_not_explicit_hs/adme-fang-perm-1_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/explicit_vs_not_explicit_hs/adme-fang-solu-1_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/explicit_vs_not_explicit_hs/adme-novartis-cyp3a4-reg_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/explicit_vs_not_explicit_hs/lipophilicity-astrazeneca_results.csv"
]

model_name_mapping = {
    "fabikru/model_15M_medium_ds_masking_30_predicted_hparams": "normal SMILES",
    "fabikru/model_15M_medium_ds_masking_0.4_explicit_hs_predicted_hparamas": "explicit hydrogens"
}

output_path = "/Users/fabian/Code/smilesencoder/plots/explicit_vs_implicit_hydrogens"

analyze_and_plot_five_experiments(csv_paths=csv_paths, model_name_mapping=model_name_mapping, output_dir=output_path, y_axis_label="")
# Out:
# Significant differences found for mse with p-value 4.877388858643744e-25
# Saved PNG plot for mse to /Users/fabian/Code/smilesencoder/plots/explicit_vs_implicit_hydrogens/mse_five_datasets_comparison.png
# Saved PDF plot for mse to /Users/fabian/Code/smilesencoder/plots/explicit_vs_implicit_hydrogens/mse_five_datasets_comparison.pdf
# Significant differences found for rho with p-value 1.5927406668778481e-24
# Saved PNG plot for rho to /Users/fabian/Code/smilesencoder/plots/explicit_vs_implicit_hydrogens/rho_five_datasets_comparison.png
# Saved PDF plot for rho to /Users/fabian/Code/smilesencoder/plots/explicit_vs_implicit_hydrogens/rho_five_datasets_comparison.pdf
# Significant differences found for r2 with p-value 2.6382040331010196e-27
# Saved PNG plot for r2 to /Users/fabian/Code/smilesencoder/plots/explicit_vs_implicit_hydrogens/r2_five_datasets_comparison.png
# Saved PDF plot for r2 to /Users/fabian/Code/smilesencoder/plots/explicit_vs_implicit_hydrogens/r2_five_datasets_comparison.pdf
# Significant differences found for mae with p-value 1.81251644079177e-26
# Saved PNG plot for mae to /Users/fabian/Code/smilesencoder/plots/explicit_vs_implicit_hydrogens/mae_five_datasets_comparison.png
# Saved PDF plot for mae to /Users/fabian/Code/smilesencoder/plots/explicit_vs_implicit_hydrogens/mae_five_datasets_comparison.pdf

# %%
def load_and_prepare_data(csv_path: str) -> Dict[str, pd.DataFrame]:
    """
    Load the CSV file and prepare data for each metric.
    
    Args:
        csv_path: Path to the CSV file containing evaluation results
        
    Returns:
        Dictionary with metric names as keys and prepared DataFrames as values
    """
    # Load the CSV file
    df = pd.read_csv(csv_path)
    
    # Create a dictionary to store prepared data for each metric
    prepared_data = {}
    
    # Get unique metrics
    metrics = df['metric_name'].unique()
    
    for metric in metrics:
        # Filter data for current metric
        metric_data = df[df['metric_name'] == metric]
        
        # Pivot the data to have models as columns and folds as rows
        pivot_data = metric_data.pivot(
            index='fold',
            columns='model',
            values='value'
        )
        
        prepared_data[metric] = pivot_data
    
    return prepared_data

# %%
def find_best_model(data: pd.DataFrame, metric_name: str) -> str:
    """
    Find the best performing model based on the metric values.
    For MAE and MSE, lower is better. For R2 and rho, higher is better.
    
    Args:
        data: DataFrame with models as columns and metric values as rows
        metric_name: Name of the metric being evaluated
        
    Returns:
        Name of the best performing model
    """
    # Calculate mean performance for each model
    model_means = data.mean()
    
    if metric_name in ['mae', 'mse']:
        # For MAE and MSE, lower is better
        best_model = model_means.idxmin()
    else:
        # For R2 and rho, higher is better
        best_model = model_means.idxmax()
    
    return best_model

# %%
csv_paths = [
    "/home/ubuntu/smiles_encoder/experiments/explicit_vs_not_explicit_hs/adme-fang-hclint-1_results.csv",
    "/home/ubuntu/smiles_encoder/experiments/explicit_vs_not_explicit_hs/adme-fang-perm-1_results.csv",
    "/home/ubuntu/smiles_encoder/experiments/explicit_vs_not_explicit_hs/adme-fang-solu-1_results.csv",
    "/home/ubuntu/smiles_encoder/experiments/explicit_vs_not_explicit_hs/adme-novartis-cyp3a4-reg_results.csv",
    "/home/ubuntu/smiles_encoder/experiments/explicit_vs_not_explicit_hs/lipophilicity-astrazeneca_results.csv"
]

for csv_path in csv_paths:
    # Load and prepare the data
    prepared_data = load_and_prepare_data(csv_path)

    for metric, metric_data in prepared_data.items():
        # Perform repeated measures ANOVA
        anova_results = repeated_measures_anova(metric_data)
        
        # Check if the ANOVA result is significant (p < 0.05)
        if anova_results['p_value'] < 0.05:
            print(f"Significant differences found for {metric} (p = {anova_results['p_value']:.4f})")
            
            # Find the best performing model
            best_model = find_best_model(metric_data, metric)
            print(f"Best performing model for {metric}: {best_model}")
            
            # Perform Tukey's HSD test
            tukey_results = tukey_hsd(metric_data)
            
            # Create and display the plot
            plt.figure(figsize=(10, 6))
            tukey_results['results'].plot_simultaneous(comparison_name=best_model)
            plt.title(f"Tukey HSD Test Results for {metric.upper()} for {csv_path.split('/')[-1]}")
            plt.tight_layout()
            plt.show()
        else:
            print(f"No significant differences found for {csv_path} with {metric}")
# Out:
# Significant differences found for mae (p = 0.0000)
# Best performing model for mae: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for mse (p = 0.0000)
# Best performing model for mse: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for r2 (p = 0.0000)
# Best performing model for r2: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for rho (p = 0.0000)
# Best performing model for rho: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for mae (p = 0.0000)
# Best performing model for mae: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for mse (p = 0.0000)
# Best performing model for mse: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for r2 (p = 0.0000)
# Best performing model for r2: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for rho (p = 0.0000)
# Best performing model for rho: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for mae (p = 0.0000)
# Best performing model for mae: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for mse (p = 0.0000)
# Best performing model for mse: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for r2 (p = 0.0000)
# Best performing model for r2: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for rho (p = 0.0000)
# Best performing model for rho: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for mae (p = 0.0000)
# Best performing model for mae: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for mse (p = 0.0000)
# Best performing model for mse: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for r2 (p = 0.0000)
# Best performing model for r2: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for rho (p = 0.0000)
# Best performing model for rho: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for mae (p = 0.0000)
# Best performing model for mae: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for mse (p = 0.0000)
# Best performing model for mse: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for r2 (p = 0.0000)
# Best performing model for r2: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
# Significant differences found for rho (p = 0.0000)
# Best performing model for rho: fabikru/model_15M_medium_ds_masking_30_predicted_hparams
