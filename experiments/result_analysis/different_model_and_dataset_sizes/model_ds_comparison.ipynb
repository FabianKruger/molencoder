# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from typing import Dict, Any
import logging
from molencoder.evaluation.statistical_evaluation import repeated_measures_anova, tukey_hsd
from molencoder.utils.experiment_plotting import analyze_and_plot_five_experiments

# %%
model_name_mapping = {
    "fabikru/model_5M_large_ds_masking_30_predicted_hparams": "5M pubchem + chembl",
    "fabikru/model_5M_medium_ds_masking_30_predicted_hparams": "5M chembl",
    "fabikru/model_5M_small_ds_masking_30_predicted_hparams": "5M half of chembl",
    "fabikru/model_15M_large_ds_masking_30_predicted_hparams": "15M pubchem + chembl",
    "fabikru/model_15M_medium_ds_masking_30_predicted_hparams": "15M chembl",
    "fabikru/model_15M_small_ds_masking_30_predicted_hparams": "15M half of chembl",
    "fabikru/model_111M_large_ds_masking_30_predicted_hparams": "111M pubchem + chembl",
    "fabikru/model_111M_medium_ds_masking_30_predicted_hparams": "111M chembl",
    "fabikru/model_111M_small_ds_masking_30_predicted_hparams": "111M half of chembl",
    "fabikru/untrained_model_5M": "5M baseline (no pretraining)",
    "fabikru/untrained_model_15M": "15M baseline (no pretraining)",
    "fabikru/untrained_model_111M": "111M baseline (no pretraining)"
}


csv_paths = [
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/adme-fang-HCLint-1_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/lipophilicity-astrazeneca_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/adme-fang-PERM-1_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/adme-fang-SOLU-1_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/adme-novartis-cyp3a4-reg_results.csv"
]

output_folder = "/Users/fabian/Code/smilesencoder/plots/model_and_dataset_sizes"


analyze_and_plot_five_experiments(csv_paths, model_name_mapping, output_folder, y_axis_label="")
# Out:
# Significant differences found for mae with p-value 1.641475291539163e-193
# Saved PNG plot for mae to /Users/fabian/Code/smilesencoder/plots/model_and_dataset_sizes/mae_five_datasets_comparison.png
# Saved PDF plot for mae to /Users/fabian/Code/smilesencoder/plots/model_and_dataset_sizes/mae_five_datasets_comparison.pdf
# Significant differences found for r2 with p-value 1.684571071716464e-192
# Saved PNG plot for r2 to /Users/fabian/Code/smilesencoder/plots/model_and_dataset_sizes/r2_five_datasets_comparison.png
# Saved PDF plot for r2 to /Users/fabian/Code/smilesencoder/plots/model_and_dataset_sizes/r2_five_datasets_comparison.pdf
# Significant differences found for rho with p-value 2.752211354388868e-192
# Saved PNG plot for rho to /Users/fabian/Code/smilesencoder/plots/model_and_dataset_sizes/rho_five_datasets_comparison.png
# Saved PDF plot for rho to /Users/fabian/Code/smilesencoder/plots/model_and_dataset_sizes/rho_five_datasets_comparison.pdf
# ...

# %%
# Import the new function (add this to your existing imports)
from smilesencoder.utils.experiment_plotting import heatmap_performance

# Use your existing variables
model_name_mapping = {
    "fabikru/model_5M_large_ds_masking_30_predicted_hparams": "5M pubchem + chembl",
    "fabikru/model_5M_medium_ds_masking_30_predicted_hparams": "5M chembl",
    "fabikru/model_5M_small_ds_masking_30_predicted_hparams": "5M half of chembl",
    "fabikru/model_15M_large_ds_masking_30_predicted_hparams": "15M pubchem + chembl",
    "fabikru/model_15M_medium_ds_masking_30_predicted_hparams": "15M chembl",
    "fabikru/model_15M_small_ds_masking_30_predicted_hparams": "15M half of chembl",
    "fabikru/model_111M_large_ds_masking_30_predicted_hparams": "111M pubchem + chembl",
    "fabikru/model_111M_medium_ds_masking_30_predicted_hparams": "111M chembl",
    "fabikru/model_111M_small_ds_masking_30_predicted_hparams": "111M half of chembl",
    "fabikru/untrained_model_5M": "5M baseline (no pretraining)",
    "fabikru/untrained_model_15M": "15M baseline (no pretraining)",
    "fabikru/untrained_model_111M": "111M baseline (no pretraining)"
}

csv_paths = [
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/adme-fang-HCLint-1_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/lipophilicity-astrazeneca_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/adme-fang-PERM-1_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/adme-fang-SOLU-1_results.csv",
    "/Users/fabian/Code/smilesencoder/experiments/cross_val_mask_30_models/adme-novartis-cyp3a4-reg_results.csv"
]

output_folder = "/Users/fabian/Code/smilesencoder/plots/model_and_dataset_sizes"

# Test the new heatmap function
heatmap_performance(csv_paths, model_name_mapping, output_folder)
# Out:
# HCLint - R2 - 95% Confidence Intervals:
#   111M baseline (no pretraining): 0.086 ± 0.054
#   111M chembl: 0.318 ± 0.054
#   111M half of chembl: 0.353 ± 0.054
#   111M pubchem + chembl: 0.341 ± 0.054
#   15M baseline (no pretraining): 0.214 ± 0.054
#   15M chembl: 0.391 ± 0.054
#   15M half of chembl: 0.400 ± 0.054
#   15M pubchem + chembl: 0.268 ± 0.054
#   5M baseline (no pretraining): 0.237 ± 0.054
#   5M chembl: 0.302 ± 0.054
#   5M half of chembl: 0.278 ± 0.054
#   5M pubchem + chembl: 0.235 ± 0.054
#
# Lipophilicity - R2 - 95% Confidence Intervals:
#   111M baseline (no pretraining): 0.171 ± 0.057
#   111M chembl: 0.635 ± 0.057
#   111M half of chembl: 0.641 ± 0.057
#   111M pubchem + chembl: 0.647 ± 0.057
#   15M baseline (no pretraining): 0.384 ± 0.057
#   15M chembl: 0.685 ± 0.057
#   15M half of chembl: 0.692 ± 0.057
#   15M pubchem + chembl: 0.632 ± 0.057
#   5M baseline (no pretraining): 0.371 ± 0.057
#   5M chembl: 0.628 ± 0.057
#   5M half of chembl: 0.611 ± 0.057
# ...
